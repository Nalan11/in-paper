# %% [markdown]
# # ML Model Stress Test & Evaluation
#
# This notebook evaluates the stability, performance, and resource usage (VRAM) of the VLM and LLM pipeline.
#
# ## 1. Environment & Connectivity Check
# Verifies libraries, GPU, and vLLM server endpoints.

# %%
import os
import time
import json
import pandas as pd
import subprocess
import paddle
from paddleocr import PaddleOCRVL
from openai import OpenAI
from pathlib import Path

print("Checking Paddle version:", paddle.__version__)
if paddle.is_compiled_with_cuda():
    paddle.set_device('gpu')
    print("GPU detected and active.")
else:
    print("WARNING: GPU NOT DETECTED. Paddle using CPU.")

# Connectivity Check: vLLM VLM Server (port 8000)
try:
    vlm_pipeline = PaddleOCRVL(
        vl_rec_backend="vllm-server",
        vl_rec_server_url="http://localhost:8000/v1",
        vl_rec_api_model_name="PaddlePaddle/PaddleOCR-VL"
    )
    print("VLM Server (8000) connectivity: SUCCESS")
except Exception as e:
    print(f"VLM Server (8000) connectivity: FAILED - {e}")

# Connectivity Check: vLLM LLM Server (port 8001)
try:
    client = OpenAI(base_url="http://localhost:8001/v1", api_key="EMPTY")
    client.models.list()
    print("LLM Server (8001) connectivity: SUCCESS")
except Exception as e:
    print(f"LLM Server (8001) connectivity: FAILED - {e}")

print("\nAll libraries and endpoints verified.")
# Out:
# /system/conda/miniconda3/envs/cloudspace/lib/python3.12/site-packages/paddle/utils/cpp_extension/extension_utils.py:712: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# /system/conda/miniconda3/envs/cloudspace/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (7.4.0.post2)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# Creating model: ('PP-DocLayoutV3', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/teamspace/studios/this_studio/.paddlex/official_models/PP-DocLayoutV3`.
# Checking Paddle version: 3.3.0
# GPU detected and active.
# Creating model: ('PaddleOCR-VL-1.5-0.9B', None)
# VLM Server (8000) connectivity: SUCCESS
# [2026-04-10 08:37:36,435] [    INFO] _client.py:1025 - HTTP Request: GET http://localhost:8001/v1/models "HTTP/1.1 200 OK"
# LLM Server (8001) connectivity: SUCCESS
#
# All libraries and endpoints verified.

# %% [markdown]
# ## 2. Logger & Monitor Setup
# Defining the `StressTestManager` to track metrics, errors, and VRAM.

# %%
class StressTestManager:
    def __init__(self, test_name, log_csv="stress_test_log.csv"):
        self.test_name = test_name
        self.log_csv = log_csv
        self.results = []
        
    def get_vram_usage(self):
        """Extracts current VRAM usage using nvidia-smi."""
        try:
            result = subprocess.check_output(
                ["nvidia-smi", "--query-gpu=memory.used", "--format=csv,nounits,noheader"],
                encoding='utf-8'
            )
            return int(result.strip())
        except:
            return 0

    def log_run(self, file_name, model_name, start_time, end_time, status="success", error_msg="", output_file=""):
        duration = end_time - start_time
        vram = self.get_vram_usage()
        
        entry = {
            "test_scenario": self.test_name,
            "model_name": model_name,
            "file_name": file_name,
            "start_time": time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start_time)),
            "end_time": time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(end_time)),
            "time_taken_sec": round(duration, 3),
            "vram_used_mb": vram,
            "status": status,
            "error": error_msg,
            "output_file": output_file
        }
        self.results.append(entry)
        
    def save_to_csv(self):
        df = pd.DataFrame(self.results)
        if os.path.exists(self.log_csv):
            df.to_csv(self.log_csv, mode='a', header=False, index=False)
        else:
            df.to_csv(self.log_csv, index=False)
        print(f"Results saved to {self.log_csv}")

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

DATASET_DIR = "falcon_invoice_dataset"
invoice_files = sorted([os.path.join(DATASET_DIR, f) for f in os.listdir(DATASET_DIR) if f.endswith(('.jpg', '.jpeg', '.png'))])
print(f"Dataset: {len(invoice_files)} images found.")
# Out:
# Dataset: 10 images found.

# %% [markdown]
# ## 3. Scenario 1: VLM Alone - Stress Test (50 Runs)
# Evaluates VLM stability and memory over a loop.

# %%
VLM_OUTPUT_DIR = "stress_results_vlm"
ensure_dir(VLM_OUTPUT_DIR)

manager = StressTestManager("VLM_Inference_Loop")
ITERATIONS = 50

print(f"Starting VLM Stress Test ({ITERATIONS} iterations)...")

for i in range(ITERATIONS):
    # Cycle through available images
    img_path = invoice_files[i % len(invoice_files)]
    file_basename = os.path.basename(img_path)
    
    start_t = time.time()
    try:
        # Running prediction
        results = vlm_pipeline.predict(img_path)
        
        # Saving result
        output_filename = f"vlm_out_{i:03d}_{file_basename}.json"
        output_path = os.path.join(VLM_OUTPUT_DIR, output_filename)
        
        # Assuming results[0] has save_to_json method from previous vlm_llm_test.ipynb usage
        results[0].save_to_json(save_path=output_path)
        
        manager.log_run(file_basename, "PaddleOCR-VL", start_t, time.time(), "success", "", output_path)
    except Exception as e:
        manager.log_run(file_basename, "PaddleOCR-VL", start_t, time.time(), "failed", str(e))
    
    if (i+1) % 10 == 0:
        print(f"Processed {i+1}/{ITERATIONS} iterations...")

manager.save_to_csv()
print("VLM Stress Test Complete.")
# Out:
# Starting VLM Stress Test (50 iterations)...
# [2026-04-10 08:40:04,443] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,480] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,485] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,487] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,489] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,492] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,518] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,534] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,616] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,624] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,636] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,640] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:04,665] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:05,042] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,785] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,787] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,794] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,799] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,807] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,821] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,828] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,874] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,916] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:06,958] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:07,024] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:07,045] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:07,282] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,948] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,953] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,958] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,960] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,976] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:08,980] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:09,007] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:09,011] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:09,133] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:09,207] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:09,448] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:11,045] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,187] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,198] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,206] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,224] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,247] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,300] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,354] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,688] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:13,775] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,188] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,193] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,281] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,308] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,318] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:15,571] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,221] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,237] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,239] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,240] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,244] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,249] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,291] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,303] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,325] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,350] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,431] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:17,566] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,102] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,107] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,116] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,139] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,156] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,186] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,199] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,223] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:19,445] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:20,901] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:20,906] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:20,932] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:20,958] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:21,004] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:21,065] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:21,275] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,709] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,749] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,797] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,818] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,828] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:22,891] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:23,288] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,754] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,759] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,768] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,783] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,785] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,831] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:24,833] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:25,615] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 10/50 iterations...
# [2026-04-10 08:40:26,969] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:26,974] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:26,979] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:26,984] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:26,985] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:26,988] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,019] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,036] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,114] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,122] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,139] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,143] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,168] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:27,532] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,820] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,842] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,849] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,854] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,860] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,862] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,865] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,917] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:28,960] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:29,002] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:29,064] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:29,076] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:29,325] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,732] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,735] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,740] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,746] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,761] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,769] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,793] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,796] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,915] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:30,998] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:31,234] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:32,788] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,064] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,067] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,068] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,073] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,085] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,136] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,190] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,524] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:34,615] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:35,861] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:35,870] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:35,947] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:35,982] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:35,986] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:36,228] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,453] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,478] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,480] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,482] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,486] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,491] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,532] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,545] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,554] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,587] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,673] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:37,807] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,033] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,035] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,046] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,063] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,081] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,110] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,122] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,147] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:39,373] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,610] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,617] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,647] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,674] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,718] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:40,782] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:41,004] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,292] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,331] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,386] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,403] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,407] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,473] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:42,874] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,095] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,104] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,108] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,110] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,126] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,160] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,164] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:44,948] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 20/50 iterations...
# [2026-04-10 08:40:46,319] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,323] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,329] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,330] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,332] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,336] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,368] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,386] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,463] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,476] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,488] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,492] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,517] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:46,883] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:47,967] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,189] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,199] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,200] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,203] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,212] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,221] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,261] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,307] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,349] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,416] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,436] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:48,674] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,043] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,046] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,050] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,052] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,065] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,073] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,100] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,102] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,221] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,304] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:50,547] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:52,117] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,387] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,389] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,391] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,396] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,408] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,459] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,514] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,849] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:53,939] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,183] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,189] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,267] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,304] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,309] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:55,578] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,680] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,832] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,846] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,849] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,854] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,856] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,891] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,913] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,929] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:56,954] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:57,032] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:57,170] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,392] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,395] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,404] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,426] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,439] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,469] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,481] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,506] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:58,731] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:59,974] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:40:59,977] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:00,007] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:00,033] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:00,076] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:00,143] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:00,354] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,648] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,688] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,743] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,760] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,764] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:01,832] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:02,235] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,462] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,466] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,471] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,475] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,492] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,531] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:03,536] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:04,308] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 30/50 iterations...
# [2026-04-10 08:41:05,751] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,754] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,764] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,770] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,772] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,778] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,807] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,841] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,917] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,933] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,946] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,950] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:05,975] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:06,340] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,431] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,433] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,645] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,655] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,657] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,672] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,674] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,715] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,758] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,800] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,867] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:07,887] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:08,125] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,473] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,475] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,478] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,480] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,494] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,503] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,530] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,533] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,651] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,730] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:09,984] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:11,559] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,835] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,838] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,844] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,848] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,858] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,908] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:12,962] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:13,297] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:13,388] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,609] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,614] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,695] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,728] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,732] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:14,988] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,700] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,713] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,716] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,717] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,722] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,727] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,770] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,778] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,799] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,829] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:16,909] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:17,043] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# [2026-04-10 08:41:19,837] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:19,876] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:19,902] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:19,945] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:20,010] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:20,223] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,518] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,557] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,612] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,630] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,635] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:21,699] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:22,102] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,319] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,328] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,332] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,336] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,350] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,388] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:23,390] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:24,162] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 40/50 iterations...
# [2026-04-10 08:41:25,264] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,604] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,611] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,614] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,620] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,626] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,661] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,679] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,761] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,778] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,792] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,798] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:25,827] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:26,209] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,302] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,524] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,526] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,532] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,537] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,538] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,554] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,599] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,641] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,678] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,745] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:27,761] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:28,008] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,367] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,369] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,378] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,380] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,394] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,404] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,429] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,432] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,550] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,629] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:29,877] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:31,468] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,742] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,744] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,746] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,750] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,762] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,815] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:32,870] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:33,205] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:33,295] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,528] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,532] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,613] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,646] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,650] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:34,912] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,054] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,156] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,161] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,166] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,175] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,179] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,210] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,232] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,253] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,278] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,360] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:36,487] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,705] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,707] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,717] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,740] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,753] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,782] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,794] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:37,822] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:38,052] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,266] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,270] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,301] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,326] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,369] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,434] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:39,644] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:40,938] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:40,978] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:41,032] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:41,049] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:41,053] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:41,119] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:41,520] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,742] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,750] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,755] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,757] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,772] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,809] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:42,814] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:41:43,584] [    INFO] _client.py:1740 - HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 50/50 iterations...
# Results saved to stress_test_log.csv
# VLM Stress Test Complete.

# %% [markdown]
# ## 4. Scenario 2: LLM Alone - Stress Test (50 Runs)
# Passes VLM outputs to LLM for data extraction.

# %%
LLM_OUTPUT_DIR = "stress_results_llm"
ensure_dir(LLM_OUTPUT_DIR)

manager = StressTestManager("LLM_Extraction_Loop")
vlm_jsons = sorted([os.path.join(VLM_OUTPUT_DIR, f) for f in os.listdir(VLM_OUTPUT_DIR) if f.endswith('.json')])

system_prompt = """You are a precise data extraction assistant. Extract information and return valid JSON per this schema:
{
  "Person_name": "string", "Company_name": "string", "address": "string", "contact": "string",
  "invoice_number": "string", "invoice_date": "YYYY-MM-DD", "due_date": "YYYY-MM-DD",
  "subtotal": "float", "tax": "float", "total": "float"
}"""

def get_raw_content(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    contents = []
    # Handle both list and dict results if structure varies
    block_list = data[0]['parsing_res_list'] if isinstance(data, list) else data['parsing_res_list']
    for block in block_list:
        if 'content' in block and block['content']:
            contents.append(block['content'])
    return "\n".join(contents)

print(f"Starting LLM Stress Test ({len(vlm_jsons)} VLM files found)...")

for i, json_path in enumerate(vlm_jsons[:50]): # Cap at 50 if more exist
    file_basename = os.path.basename(json_path)
    start_t = time.time()
    
    try:
        raw_text = get_raw_content(json_path)
        
        response = client.chat.completions.create(
            model="Qwen2.5-1.5B",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": f"Text to process:\n{raw_text}"}
            ],
            temperature=0.1,
            response_format={"type": "json_object"}
        )
        
        llm_json = response.choices[0].message.content
        output_filename = file_basename.replace(".json", "_llm.txt")
        output_path = os.path.join(LLM_OUTPUT_DIR, output_filename)
        
        with open(output_path, 'w') as f:
            f.write(llm_json)
            
        manager.log_run(file_basename, "Qwen2.5-1.5B", start_t, time.time(), "success", "", output_path)
    except Exception as e:
        manager.log_run(file_basename, "Qwen2.5-1.5B", start_t, time.time(), "failed", str(e))

    if (i+1) % 10 == 0:
        print(f"Processed {i+1}/{min(50, len(vlm_jsons))} iterations...")

manager.save_to_csv()
print("LLM Stress Test Complete.")
# Out:
# Starting LLM Stress Test (50 VLM files found)...
# [2026-04-10 08:46:41,316] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:42,466] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:43,615] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:44,764] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:45,923] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:47,080] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:48,227] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:49,376] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:50,525] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:51,679] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 10/50 iterations...
# [2026-04-10 08:46:52,831] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:53,988] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:55,137] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:56,293] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:57,441] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:58,590] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:46:59,740] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:00,892] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:02,048] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:03,198] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 20/50 iterations...
# [2026-04-10 08:47:04,348] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:05,500] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:06,663] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:07,813] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:08,972] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:10,123] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:11,281] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:12,438] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:13,590] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:14,741] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 30/50 iterations...
# [2026-04-10 08:47:15,893] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:17,050] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:18,200] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:19,352] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:20,504] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:21,665] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:22,817] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:23,974] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:25,131] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:26,296] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 40/50 iterations...
# [2026-04-10 08:47:27,457] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:28,609] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:29,761] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:30,919] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:32,077] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:33,229] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:34,380] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:35,532] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:36,696] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 08:47:37,851] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 50/50 iterations...
# Results saved to stress_test_log.csv
# LLM Stress Test Complete.

# %%
LLM_OUTPUT_DIR = "stress_results_llm"
# Assuming ensure_dir is defined elsewhere in your notebook
ensure_dir(LLM_OUTPUT_DIR)

# Assuming StressTestManager is defined elsewhere
manager = StressTestManager("LLM_Extraction_Loop")

# Assuming VLM_OUTPUT_DIR is defined elsewhere (e.g., VLM_OUTPUT_DIR = "stress_results_vlm")
vlm_jsons = sorted([os.path.join(VLM_OUTPUT_DIR, f) for f in os.listdir(VLM_OUTPUT_DIR) if f.endswith('.json')])

system_prompt = """You are a precise data extraction assistant. Extract information and return valid JSON per this schema:
{
  "Person_name": "string", "Company_name": "string", "address": "string", "contact": "string",
  "invoice_number": "string", "invoice_date": "YYYY-MM-DD", "due_date": "YYYY-MM-DD",
  "subtotal": "float", "tax": "float", "total": "float"
}"""

def get_raw_content(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    contents = []
    
    # Safely get the parsing_res_list from the top-level dictionary
    if isinstance(data, dict):
        block_list = data.get('parsing_res_list', [])
    elif isinstance(data, list) and len(data) > 0:
        block_list = data[0].get('parsing_res_list', [])
    else:
        block_list = []

    for block in block_list:
        if isinstance(block, dict):
            # Target the specific key found in your JSON: 'block_content'
            text_value = block.get('block_content')
            
            # Append if it exists and isn't just empty space
            if text_value and str(text_value).strip():
                contents.append(str(text_value).strip())
                
    return "\n".join(contents)

print(f"Starting LLM Stress Test ({len(vlm_jsons)} VLM files found)...")

for i, json_path in enumerate(vlm_jsons[:50]): # Cap at 50 if more exist
    file_basename = os.path.basename(json_path)
    start_t = time.time()
    
    try:
        raw_text = get_raw_content(json_path)
        
        # Make sure 'client' is properly initialized via the OpenAI SDK before this loop!
        response = client.chat.completions.create(
            model="Qwen2.5-1.5B",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": f"Text to process:\n{raw_text}"}
            ],
            temperature=0.1,
            response_format={"type": "json_object"}
        )
        
        llm_json = response.choices[0].message.content
        output_filename = file_basename.replace(".json", "_llm.txt")
        output_path = os.path.join(LLM_OUTPUT_DIR, output_filename)
        
        with open(output_path, 'w') as f:
            f.write(llm_json)
            
        manager.log_run(file_basename, "Qwen2.5-1.5B", start_t, time.time(), "success", "", output_path)
    except Exception as e:
        manager.log_run(file_basename, "Qwen2.5-1.5B", start_t, time.time(), "failed", str(e))

    if (i+1) % 10 == 0:
        print(f"Processed {i+1}/{min(50, len(vlm_jsons))} iterations...")

manager.save_to_csv()
print("LLM Stress Test Complete.")
# Out:
# Starting LLM Stress Test (50 VLM files found)...
# [2026-04-10 09:25:53,540] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:25:55,834] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:25:55,909] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2026-04-10 09:25:58,197] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:00,321] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:02,614] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:04,809] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:06,924] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:09,383] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:11,812] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 10/50 iterations...
# [2026-04-10 09:26:14,594] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:17,030] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:17,068] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2026-04-10 09:26:19,347] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:21,270] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:23,364] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:25,605] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:27,903] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:30,363] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:32,795] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 20/50 iterations...
# [2026-04-10 09:26:35,670] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:38,116] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:38,153] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2026-04-10 09:26:40,441] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:42,579] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:45,082] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:47,286] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:49,389] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:51,856] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:54,290] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 30/50 iterations...
# [2026-04-10 09:26:57,071] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:59,364] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:26:59,403] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2026-04-10 09:27:01,668] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:03,786] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:06,083] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:08,275] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:10,380] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:12,851] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:15,286] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 40/50 iterations...
# [2026-04-10 09:27:18,074] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:20,520] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:20,572] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2026-04-10 09:27:22,870] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:25,006] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:27,523] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:29,709] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:32,000] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:34,256] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# [2026-04-10 09:27:36,692] [    INFO] _client.py:1025 - HTTP Request: POST http://localhost:8001/v1/chat/completions "HTTP/1.1 200 OK"
# Processed 50/50 iterations...
# Results saved to stress_test_log.csv
# LLM Stress Test Complete.

# %% [markdown]
# ## 5. Scenario 3: Pipeline Lifecycle + VLM Stress Test (50 Runs)
# Initializes pipeline AND runs inference in each loop to check for memory leaks during creation.

# %%
LIFECYCLE_OUTPUT_DIR = "stress_results_lifecycle"
ensure_dir(LIFECYCLE_OUTPUT_DIR)

manager = StressTestManager("Pipeline_Lifecycle_Loop")
ITERATIONS = 50

print(f"Starting Lifecycle Stress Test ({ITERATIONS} iterations)...")

for i in range(ITERATIONS):
    img_path = invoice_files[i % len(invoice_files)]
    file_basename = os.path.basename(img_path)
    start_t = time.time()
    
    try:
        # 1. Initialize Pipeline
        temp_pipeline = PaddleOCRVL(
            vl_rec_backend="vllm-server",
            vl_rec_server_url="http://localhost:8000/v1",
            vl_rec_api_model_name="PaddlePaddle/PaddleOCR-VL"
        )
        
        # 2. Predict
        results = temp_pipeline.predict(img_path)
        
        # 3. Save
        output_path = os.path.join(LIFECYCLE_OUTPUT_DIR, f"lifecycle_out_{i:03d}.json")
        results[0].save_to_json(save_path=output_path)
        
        # 4. Explicitly delete (help GC if possible, though Paddle objects may persist in C++ memory)
        del temp_pipeline
        
        manager.log_run(file_basename, "PaddleOCR-VL_FullLifecycle", start_t, time.time(), "success", "", output_path)
    except Exception as e:
        manager.log_run(file_basename, "PaddleOCR-VL_FullLifecycle", start_t, time.time(), "failed", str(e))
    
    if (i+1) % 10 == 0:
        print(f"Processed {i+1}/{ITERATIONS} iterations...")

manager.save_to_csv()
print("Lifecycle Stress Test Complete.")

# %% [markdown]
# ## 6. Summary Statistics & Error Rates

# %%
if os.path.exists("stress_test_log.csv"):
    df = pd.read_csv("stress_test_log.csv")
    
    summary = df.groupby(['test_scenario', 'status']).agg({
        'time_taken_sec': ['mean', 'max', 'min', 'count'],
        'vram_used_mb': ['mean', 'max']
    })
    
    print("--- STRESS TEST SUMMARY ---")
    display(summary)
    
    error_counts = df[df['status'] == 'failed'].groupby('test_scenario').size()
    total_counts = df.groupby('test_scenario').size()
    error_rate = (error_counts / total_counts * 100).fillna(0)
    
    print("\n--- ERROR RATES (%) ---")
    print(error_rate)
else:
    print("No log file found. Ensure scenarios have run.")
